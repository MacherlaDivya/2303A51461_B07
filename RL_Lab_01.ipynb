# %% [markdown]
# <a href="https://colab.research.google.com/github/MacherlaDivya/2303A51461_B07/blob/main/RL_Lab_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **1. Arithmetic Mean Method**

# %%
n=int(input("Enter number of machines: "))
machines={}
for i in range(n):
    name=input("Enter machine name: ")
    rewards=list(map(int,input("Enter rewards: ").split()))
    machines[name]=rewards

best=None
high=float('-inf')

for name,rewards in machines.items():
    q=sum(rewards)/len(rewards)
    print(f"Machine {name}")
    print(f"Rewards: {rewards}")
    print(f"Q({name}) = {q:.2f}")
    if q>high:
        high=q
        best=name

print("Greedy Selected Machine:",best)
# Out:
# Enter number of machines: 3
# Enter machine name: A
# Enter rewards: 3 2 4
# Enter machine name: B
# Enter rewards: 6 7
# Enter machine name: C
# Enter rewards: 5 4 6
# Machine A
# Rewards: [3, 2, 4]
# Q(A) = 3.00
# Machine B
# Rewards: [6, 7]
# Q(B) = 6.50
# Machine C
# Rewards: [5, 4, 6]
# Q(C) = 5.00
# Greedy Selected Machine: B

# %% [markdown]
# ### **2. Incremental Update Method**

# %%
n=int(input("Enter number of machines: "))
q=[0]*n
count=[0]*n
names=[]

for i in range(n):
    name=input("Enter machine name: ")
    names.append(name)
    rewards=list(map(int,input("Enter rewards: ").split()))
    print(f"\nMachine {name}")
    for r in rewards:
        count[i]+=1
        q[i]=q[i]+(r-q[i])/count[i]
        print(f"Reward: {r}, N={count[i]}, Q={q[i]:.2f}")
    print(f"Final Q({name}) = {q[i]:.2f}")

best=q.index(max(q))
print("\nGreedy Selected Machine:",names[best])
# Out:
# Enter number of machines: 3
# Enter machine name: A
# Enter rewards: 3 2 4
#
# Machine A
# Reward: 3, N=1, Q=3.00
# Reward: 2, N=2, Q=2.50
# Reward: 4, N=3, Q=3.00
# Final Q(A) = 3.00
# Enter machine name: B
# Enter rewards: 6 7
#
# Machine B
# Reward: 6, N=1, Q=6.00
# Reward: 7, N=2, Q=6.50
# Final Q(B) = 6.50
# Enter machine name: C
# Enter rewards: 5 4 6
#
# Machine C
# Reward: 5, N=1, Q=5.00
# Reward: 4, N=2, Q=4.50
# Reward: 6, N=3, Q=5.00
# Final Q(C) = 5.00
#
# Greedy Selected Machine: B
